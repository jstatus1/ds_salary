# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk

# %%
df = pd.read_csv('glassdoor_jobs_cleaned.csv')

# %%
df.head()
# Out:
#                                    Job Title              Salary Estimate  \
# 0  Data Scientist - Statistics, Early Career  $68K-$111K (Glassdoor est.)
# 1                  Data Scientist II (Miami)  $68K-$111K (Glassdoor est.)
# 2                             Data Scientist  $68K-$111K (Glassdoor est.)
# 3          Data Scientist (Growth Marketing)  $68K-$111K (Glassdoor est.)
# 4            Data Scientist/Machine Learning  $68K-$111K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  *Organization and Job ID**\nJob ID: 310918\n\n...     3.8
# 1  OfferUp is dedicated to building the simplest ...     3.4
# 2  About Us\n\n\nInterested in working for a huma...     4.7
# 3  Auth0 is a pre-IPO unicorn. We are growing rap...     4.8
# 4  PulsePoint™, a global programmatic advertising...     4.4
#
#                                  Company Name         Location  \
# 0  Pacific Northwest National Laboratory\n3.8      Seattle, WA
# 1                                OfferUp\n3.4        Miami, FL
# 2                               1904labs\n4.7  Saint Louis, MO
# 3                                  Auth0\n4.8      America, AL
# 4                             PulsePoint\n4.4     New York, NY
#
#       Headquarters                    Size  Founded  Type of ownership  ...  \
# 0     Richland, WA  1001 to 5000 employees     1965         Government  ...
# 1     Bellevue, WA    201 to 500 employees     2011  Company - Private  ...
# 2  Saint Louis, MO     51 to 200 employees     2016  Company - Private  ...
# 3     Bellevue, WA   501 to 1000 employees     2014  Company - Private  ...
# 4     New York, NY     51 to 200 employees     2011  Company - Private  ...
#
#                                company_txt     job_city job_state same_state  \
# 0  Pacific Northwest National Laboratory\n      Seattle        WA          0
# 1                                OfferUp\n        Miami        FL          0
# 2                               1904labs\n  Saint Louis        MO          1
# 3                                  Auth0\n      America        AL          0
# 4                             PulsePoint\n     New York        NY          1
#
#    company_age  python_yn  R_yn  spark_yn  aws_yn excel_yn
# 0           54          0     0         0       0        1
# 1            8          1     0         0       1        0
# 2            3          1     0         1       0        0
# 3            5          1     0         1       0        0
# 4            8          1     0         1       0        0
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'Employer Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_city', 'job_state', 'same_state', 'company_age',
#        'python_yn', 'R_yn', 'spark_yn', 'aws_yn', 'excel_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    
    if 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    elif 'data scientist' in title.lower():
        return 'data scientist'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    490
# mle                 7
# director            3
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        439
# senior     61
# Name: seniority, dtype: int64

# %%
df.job_state.value_counts()
# Out:
#  CA               94
#  VA               66
#  NY               54
#  MA               36
#  IL               29
#  TX               25
#  DC               20
#  MD               17
#  WA               15
#  OH               13
#  FL               11
#  PA               11
#  NC                9
#  AZ                8
#  MI                8
#  GA                8
#  WI                8
#  MO                8
#  CO                8
#  MN                6
#  TN                6
# United States      6
#  NJ                5
#  OR                3
#  CT                3
#  AL                3
#  NM                2
# New Jersey         2
#  IN                2
# Utah               2
#  UT                2
#  NE                2
#  WV                2
# New York State     1
# Virginia           1
#  OK                1
#  KY                1
# California         1
#  NH                1
# Name: job_state, dtype: int64

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      5278
# 1      3860
# 2      5020
# 3      4512
# 4      3741
#        ...
# 495    3460
# 496    2929
# 497    5081
# 498    4411
# 499    2527
# Name: desc_len, Length: 500, dtype: int64

# %%
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['Competitors']
# Out:
# 0      Oak Ridge National Laboratory, National Renewa...
# 1                                Letgo, 5miles, Facebook
# 2                   Slalom, Daugherty Business Solutions
# 3                                                     -1
# 4       Crossix Solutions Inc., AppNexus, The Trade Desk
#                              ...
# 495                                                   -1
# 496                                                   -1
# 497                                                   -1
# 498                                                   -1
# 499                                                   -1
# Name: Competitors, Length: 500, dtype: object

# %%
#hourly wage to annual

df['min _salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis= 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis= 1)

# %%
df[['hourly', 'min_salary', 'max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 0         0          68         111
# 1         0          68         111
# 2         0          68         111
# 3         0          68         111
# 4         0          68         111
# ..      ...         ...         ...
# 495       0          95         118
# 496       0          95         118
# 497       0          95         118
# 498       0          95         118
# 499       0          95         118
#
# [500 rows x 3 columns]

# %%
df['company_txt']=df.company_txt.apply(lambda x: x.replace('\n', ''))
df.company_txt
# Out:
# 0      Pacific Northwest National Laboratory
# 1                                    OfferUp
# 2                                   1904labs
# 3                                      Auth0
# 4                                 PulsePoint
#                        ...
# 495                           Prescient Edge
# 496                 Rainmaker Resources, LLC
# 497                    Good Shepherd Hospice
# 498                     NetImpact Strategies
# 499                          Radiant Digital
# Name: company_txt, Length: 500, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded  hourly  Employer Provided  min_salary  \
# count  500.000000   500.000000   500.0              500.0  500.000000
# mean     3.489400  1578.656000     0.0                0.0   91.396000
# std      1.384262   801.300727     0.0                0.0   15.776977
# min     -1.000000    -1.000000     0.0                0.0   68.000000
# 25%      3.300000  1908.000000     0.0                0.0   79.000000
# 50%      3.800000  1991.000000     0.0                0.0   89.000000
# 75%      4.200000  2007.000000     0.0                0.0  106.000000
# max      5.000000  2019.000000     0.0                0.0  124.000000
#
#        max_salary  avg_salary  same_state  company_age   python_yn  \
# count  500.000000  500.000000  500.000000   500.000000  500.000000
# mean   140.492000  115.944000    0.370000    28.264000    0.806000
# std     24.637369   19.284363    0.483288    38.782502    0.395825
# min    109.000000   89.500000    0.000000     0.000000    0.000000
# 25%    128.000000  104.500000    0.000000     3.750000    1.000000
# 50%    135.000000  112.000000    0.000000    13.000000    1.000000
# 75%    151.000000  121.500000    1.000000    37.000000    1.000000
# max    198.000000  161.000000    1.000000   238.000000    1.000000
#
#              R_yn    spark_yn     aws_yn    excel_yn     desc_len    num_comp  \
# count  500.000000  500.000000  500.00000  500.000000   500.000000  500.000000
# mean     0.004000    0.304000    0.22400    0.426000  3420.364000    0.722000
# std      0.063182    0.460443    0.41734    0.494989  1604.654666    1.224629
# min      0.000000    0.000000    0.00000    0.000000    83.000000    0.000000
# 25%      0.000000    0.000000    0.00000    0.000000  2335.000000    0.000000
# 50%      0.000000    0.000000    0.00000    0.000000  3377.500000    0.000000
# 75%      0.000000    1.000000    0.00000    1.000000  4463.750000    1.000000
# max      1.000000    1.000000    1.00000    1.000000  9162.000000    3.000000
#
#        min _salary
# count   500.000000
# mean     91.396000
# std      15.776977
# min      68.000000
# 25%      79.000000
# 50%      89.000000
# 75%     106.000000
# max     124.000000

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.company_age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['company_age', 'avg_salary', 'Rating'])

# %%
df[['company_age', 'avg_salary', 'Rating', 'desc_len',"num_comp"]].corr()
# Out:
#              company_age  avg_salary    Rating  desc_len  num_comp
# company_age     1.000000    0.034326  0.104685  0.192817  0.242861
# avg_salary      0.034326    1.000000 -0.030971 -0.003304 -0.025227
# Rating          0.104685   -0.030971  1.000000  0.116763  0.126050
# desc_len        0.192817   -0.003304  0.116763  1.000000  0.205707
# num_comp        0.242861   -0.025227  0.126050  0.205707  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['company_age', 'avg_salary', 'Rating', 'desc_len', 'num_comp']].corr(), vmax=.3, center=0,
           cmap=cmap,square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'Employer Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_city', 'job_state', 'same_state', 'company_age',
#        'python_yn', 'R_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simp',
#        'seniority', 'desc_len', 'num_comp', 'min _salary'],
#       dtype='object')

# %%
#Categorical Data
df_cat = df[['Location', 'Headquarters', 'Size',  'Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state', 'same_state','python_yn', 'R_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simp',
       'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" %(i,len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 163
# graph for Headquarters: total = 197
# graph for Size: total = 9
# graph for Type of ownership: total = 12
# graph for Industry: total = 58
# graph for Sector: total = 23
# graph for Revenue: total = 14
# graph for company_txt: total = 369
# graph for job_state: total = 39
# graph for same_state: total = 2
# graph for python_yn: total = 2
# graph for R_yn: total = 2
# graph for spark_yn: total = 2
# graph for aws_yn: total = 2
# graph for excel_yn: total = 2
# graph for job_simp: total = 3
# graph for seniority: total = 2

# %%
for i in df_cat[['Location', 'Headquarters', 'company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" %(i,len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_txt: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'Employer Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_city', 'job_state', 'same_state', 'company_age',
#        'python_yn', 'R_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simp',
#        'seniority', 'desc_len', 'num_comp', 'min _salary'],
#       dtype='object')

# %%
pd.pivot_table(df, index='job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# data scientist  115.930612
# director        125.666667
# mle             112.714286

# %%
pd.pivot_table(df, index=['job_simp','seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# data scientist na         115.234884
#                senior     120.916667
# director       na         108.000000
#                senior     161.000000
# mle            na         112.714286

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)
pd.pivot_table(df, index=['job_state', 'job_simp'], values = 'avg_salary').sort_values('job_state', ascending=False)
# Out:
#                                avg_salary
# job_state      job_simp
# Virginia       data scientist  104.500000
# Utah           data scientist  127.250000
# United States  data scientist  107.333333
# New York State data scientist  148.500000
# New Jersey     data scientist  100.500000
# California     data scientist  113.500000
#  WV            data scientist  116.500000
#  WI            data scientist  118.312500
#  WA            data scientist  119.866667
#  VA            data scientist  120.140625
#                mle             116.500000
#  UT            data scientist  126.500000
#  TX            data scientist  115.940000
#  TN            data scientist  101.583333
#  PA            data scientist  111.227273
#  OR            data scientist  116.500000
#  OK            data scientist  104.500000
#  OH            data scientist  110.538462
#  NY            mle             103.000000
#                data scientist  115.451923
#  NM            data scientist  100.750000
#  NJ            data scientist  124.000000
#  NH            data scientist  143.000000
#  NE            data scientist  140.750000
#  NC            data scientist  109.944444
#  MO            data scientist  107.500000
#  MN            data scientist  114.000000
#  MI            data scientist  124.125000
#  MD            data scientist  121.264706
#  MA            data scientist  110.409091
#                director        125.666667
#  KY            data scientist  113.500000
#  IN            data scientist  127.250000
#  IL            data scientist  110.758621
#  GA            data scientist  123.812500
#  FL            data scientist  106.818182
#  DC            data scientist  113.775000
#  CT            data scientist  110.500000
#  CO            data scientist  109.437500
#  CA            data scientist  118.939560
#                mle             116.666667
#  AZ            data scientist  120.000000
#  AL            data scientist  101.833333

# %%
#rating industry, secotr, revenue, number of comp, hourly, employer provided, python r, spark aws, excel, desc_len, type of ownership
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'Employer Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_city', 'job_state', 'same_state', 'company_age',
#        'python_yn', 'R_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simp',
#        'seniority', 'desc_len', 'num_comp', 'min _salary'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'Employer Provided', 'python_yn', 'R_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values='avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# Rating
#         avg_salary
# Rating
#  2.0    148.500000
#  3.8    121.421875
#  3.1    120.681818
#  3.3    119.722222
#  3.9    118.764706
#  4.1    118.720000
#  3.5    118.576923
#  3.7    118.555556
#  4.0    118.258065
#  5.0    117.666667
#  3.2    117.409091
# -1.0    117.333333
#  4.8    116.466667
#  3.4    115.861111
#  2.6    115.625000
#  4.2    113.631579
#  3.0    113.600000
#  4.6    113.500000
#  4.9    113.400000
#  4.3    111.062500
#  2.2    110.833333
#  4.5    110.482143
#  3.6    110.456522
#  2.8    110.045455
#  2.9    109.944444
#  2.5    109.250000
#  2.7    109.000000
#  4.7    107.272727
#  4.4    106.863636
#  1.6    104.500000
# Industry
#                                           avg_salary
# Industry
# News Outlet                               148.500000
# Transportation Equipment Manufacturing    148.500000
# Construction                              148.500000
# Casual Restaurants                        148.500000
# Commercial Equipment Rental               143.000000
# Timber Operations                         140.750000
# Energy                                    128.857143
# Logistics & Supply Chain                  128.666667
# Electrical & Electronic Manufacturing     127.833333
# Banks & Credit Unions                     127.250000
# Wholesale                                 126.625000
# Financial Analytics & Research            126.500000
# Federal Agencies                          124.750000
# Colleges & Universities                   123.000000
# Staffing & Outsourcing                    119.712500
# Financial Transaction Processing          119.666667
# Internet                                  119.647059
# Telecommunications Services               119.000000
# Consulting                                118.980769
# Aerospace & Defense                       118.375000
# Architectural & Engineering Services      117.900000
# -1                                        117.745098
# IT Services                               117.396825
# Investment Banking & Asset Management     116.789474
# Education Training Services               116.500000
# Beauty & Personal Accessories Stores      116.500000
# Food & Beverage Stores                    116.500000
# Research & Development                    115.800000
# Biotech & Pharmaceuticals                 113.607143
# Food Production                           113.500000
# Other Retail Stores                       113.500000
# Health Care Services & Hospitals          113.250000
# Social Assistance                         113.071429
# Advertising & Marketing                   112.653846
# Video Games                               112.300000
# Membership Organizations                  112.000000
# Pet & Pet Supplies Stores                 112.000000
# Motion Picture Production & Distribution  112.000000
# Computer Hardware & Software              111.047619
# Consumer Products Manufacturing           110.500000
# Enterprise Software & Network Solutions   109.500000
# Brokerage Services                        108.300000
# Accounting                                108.250000
# Food & Beverage Manufacturing             108.000000
# Insurance Carriers                        107.777778
# Farm Support Services                     106.333333
# Lending                                   106.333333
# Consumer Product Rental                   104.500000
# Rail                                      104.500000
# Real Estate                               104.500000
# Security Services                         104.500000
# Industrial Manufacturing                  103.333333
# Utilities                                 101.666667
# Chemical Manufacturing                    100.333333
# Health, Beauty, & Fitness                  99.875000
# Sporting Goods Stores                      99.500000
# Telecommunications Manufacturing           93.500000
# Express Delivery Services                  89.500000
# Sector
#                                     avg_salary
# Sector
# Restaurants, Bars & Food Services   148.500000
# Construction, Repair & Maintenance  148.500000
# Government                          124.750000
# Education                           121.916667
# Oil, Gas, Energy & Utilities        120.700000
# Agriculture & Forestry              119.000000
# Business Services                   118.552083
# Aerospace & Defense                 118.375000
# -1                                  117.745098
# Media                               117.428571
# Transportation & Logistics          116.000000
# Finance                             115.565789
# Information Technology              114.241935
# Biotech & Pharmaceuticals           113.607143
# Health Care                         113.250000
# Non-Profit                          113.071429
# Manufacturing                       112.857143
# Retail                              112.142857
# Telecommunications                  110.500000
# Accounting & Legal                  108.250000
# Insurance                           107.777778
# Real Estate                         104.500000
# Consumer Services                   100.800000
# Revenue
#                                   avg_salary
# Revenue
# $2 to $5 billion (USD)            123.115385
# $1 to $2 billion (USD)            122.480000
# $50 to $100 million (USD)         118.903846
# $5 to $10 million (USD)           117.300000
# $500 million to $1 billion (USD)  117.023810
# $10 to $25 million (USD)          116.952381
# -1                                115.941176
# $5 to $10 billion (USD)           115.750000
# $100 to $500 million (USD)        115.570175
# Unknown / Non-Applicable          114.866242
# $1 to $5 million (USD)            113.960000
# $10+ billion (USD)                113.822917
# $25 to $50 million (USD)          110.250000
# Less than $1 million (USD)        109.944444
# num_comp
#           avg_salary
# num_comp
# 0         116.267218
# 3         115.190000
# 1         114.961538
# 2         114.729167
# hourly
#         avg_salary
# hourly
# 0          115.944
# Employer Provided
#                    avg_salary
# Employer Provided
# 0                     115.944
# python_yn
#            avg_salary
# python_yn
# 0          115.969072
# 1          115.937965
# R_yn
#       avg_salary
# R_yn
# 1     140.750000
# 0     115.844378
# spark_yn
#           avg_salary
# spark_yn
# 0         116.625000
# 1         114.384868
# aws_yn
#         avg_salary
# aws_yn
# 0       115.961340
# 1       115.883929
# excel_yn
#           avg_salary
# excel_yn
# 0         115.998258
# 1         115.870892
# Type of ownership
#                                 avg_salary
# Type of ownership
# Unknown                         134.250000
# Self-employed                   128.666667
# Government                      123.166667
# College / University            123.000000
# Nonprofit Organization          122.543478
# Company - Public                115.986842
# -1                              115.941176
# Subsidiary or Business Segment  115.352941
# Company - Private               114.854785
# Hospital                        110.375000
# Contract                        106.500000
# Private Practice / Firm         104.500000
# avg_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-d15e62abcff0> in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots, index = i, values='avg_salary').sort_values('avg_salary', ascending=False))
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      98         values = list(values)
#      99
# --> 100     grouped = data.groupby(keys, observed=observed)
#     101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
#     409                 observed=observed,
# --> 410                 mutated=self.mutated,
#     411             )
#     412
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     625                 in_axis=in_axis,
#     626             )
# --> 627             if not isinstance(gpr, Grouping)
#     628             else gpr
#     629         )
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     343                 if getattr(self.grouper, "ndim", 1) != 1:
#     344                     t = self.name or str(type(self.grouper))
# --> 345                     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     346                 self.grouper = self.index.map(self.grouper)
#     347                 if not (
#
# ValueError: Grouper for 'avg_salary' not 1-dimensional

# %%
pd.pivot_table(df_pivots, index= 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                          0    1
# Revenue
# $1 to $2 billion (USD)             8   17
# $1 to $5 million (USD)             5   20
# $10 to $25 million (USD)           9   33
# $10+ billion (USD)                 6   42
# $100 to $500 million (USD)         8   49
# $2 to $5 billion (USD)             4   22
# $25 to $50 million (USD)           5   15
# $5 to $10 billion (USD)            6    6
# $5 to $10 million (USD)            3   12
# $50 to $100 million (USD)          6   20
# $500 million to $1 billion (USD)   6   15
# -1                                 8    9
# Less than $1 million (USD)         2    7
# Unknown / Non-Applicable          21  136

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """removing punctuation and stop words """
    filtered = []
    stop_words = set(stopwords.words(english))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc = WordCloud(backgroud_color="white", random_state=1, stopwords=STOPWORDS, max_words=2000, width=800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-9b5296706af6> in <module>
#      11     return filtered
#      12
# ---> 13 words_filtered = punctuation_stop(words)
#      14
#      15 text = " ".join([ele for ele in words_filtered])
#
# <ipython-input-38-9b5296706af6> in punctuation_stop(text)
#       4     """removing punctuation and stop words """
#       5     filtered = []
# ----> 6     stop_words = set(stopwords.words(english))
#       7     word_tokens = word_tokenize(text)
#       8     for w in word_tokens:
#
# NameError: name 'english' is not defined
